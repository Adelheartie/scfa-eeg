# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from scipy.io import loadmat
import numpy as np

eeg_path = '/content/drive/MyDrive/eeg project/Subject01_s1.mat'
mat_data = loadmat(eeg_path)
run = mat_data['run']
main_struct = run[0][0]

# %%
run = mat_data['run']

# %%
# Check what is inside the main block
for i, item in enumerate(run[0][0]):
    print(f"Index {i}: Type: {type(item)}")
# Out:
# Index 0: Type: <class 'numpy.ndarray'>

# %%
print(run[0][0][0])
# Out:
# [(array([[ 8987.96776658,  -853.57654873,  -754.98298091, ...,
#           5398.00564992, 21808.41282764,  6147.94176423],
#         [ 8979.71778182,  -860.98278505,  -753.70173327, ...,
#           5416.84936511, 21821.38155367,  6165.4417319 ],
#         [ 8980.99902946,  -856.67029301,  -749.04549188, ...,
#           5411.69312463, 21819.06905795,  6167.00422901],
#         ...,
#         [ 8933.09286798,  -685.7643588 ,  -560.88958954, ...,
#           5334.00576818, 21561.78828334,  6204.75415926],
#         [ 8925.31163235,  -692.70184599,  -568.98332459, ...,
#           5333.47451916, 21559.3195379 ,  6205.81665729],
#         [ 8919.03039396,  -697.2955875 ,  -574.7645639 , ...,
#           5339.44325813, 21562.53828195,  6210.59789846]]), array([[(array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[512]], dtype=uint16), array([[array(['Fp1'], dtype='<U3')],
#                 [array(['AF7'], dtype='<U3')],
#                 [array(['AF3'], dtype='<U3')],
#                 [array(['F1'], dtype='<U2')],
#                 [array(['F3'], dtype='<U2')],
#                 [array(['F5'], dtype='<U2')],
#                 [array(['F7'], dtype='<U2')],
#                 [array(['FT7'], dtype='<U3')],
#                 [array(['FC5'], dtype='<U3')],
#                 [array(['FC3'], dtype='<U3')],
#                 [array(['FC1'], dtype='<U3')],
#                 [array(['C1'], dtype='<U2')],
#                 [array(['C3'], dtype='<U2')],
#                 [array(['C5'], dtype='<U2')],
#                 [array(['T7'], dtype='<U2')],
#                 [array(['TP7'], dtype='<U3')],
#                 [array(['CP5'], dtype='<U3')],
#                 [array(['CP3'], dtype='<U3')],
#                 [array(['CP1'], dtype='<U3')],
#                 [array(['P1'], dtype='<U2')],
#                 [array(['P3'], dtype='<U2')],
#                 [array(['P5'], dtype='<U2')],
#                 [array(['P7'], dtype='<U2')],
#                 [array(['P9'], dtype='<U2')],
#                 [array(['PO7'], dtype='<U3')],
#                 [array(['PO3'], dtype='<U3')],
#                 [array(['O1'], dtype='<U2')],
#                 [array(['Iz'], dtype='<U2')],
#                 [array(['Oz'], dtype='<U2')],
#                 [array(['POz'], dtype='<U3')],
#                 [array(['Pz'], dtype='<U2')],
#                 [array(['CPz'], dtype='<U3')],
#                 [array(['Fpz'], dtype='<U3')],
#                 [array(['Fp2'], dtype='<U3')],
#                 [array(['AF8'], dtype='<U3')],
#                 [array(['AF4'], dtype='<U3')],
#                 [array(['AFz'], dtype='<U3')],
#                 [array(['Fz'], dtype='<U2')],
#                 [array(['F2'], dtype='<U2')],
#                 [array(['F4'], dtype='<U2')],
#                 [array(['F6'], dtype='<U2')],
#                 [array(['F8'], dtype='<U2')],
#                 [array(['FT8'], dtype='<U3')],
#                 [array(['FC6'], dtype='<U3')],
#                 [array(['FC4'], dtype='<U3')],
#                 [array(['FC2'], dtype='<U3')],
#                 [array(['FCz'], dtype='<U3')],
#                 [array(['Cz'], dtype='<U2')],
#                 [array(['C2'], dtype='<U2')],
#                 [array(['C4'], dtype='<U2')],
#                 [array(['C6'], dtype='<U2')],
#                 [array(['T8'], dtype='<U2')],
#                 [array(['TP8'], dtype='<U3')],
#                 [array(['CP6'], dtype='<U3')],
#                 [array(['CP4'], dtype='<U3')],
#                 [array(['CP2'], dtype='<U3')],
#                 [array(['P2'], dtype='<U2')],
#                 [array(['P4'], dtype='<U2')],
#                 [array(['P6'], dtype='<U2')],
#                 [array(['P8'], dtype='<U2')],
#                 [array(['P10'], dtype='<U3')],
#                 [array(['PO8'], dtype='<U3')],
#                 [array(['PO4'], dtype='<U3')],
#                 [array(['O2'], dtype='<U2')],
#                 [array(['Status'], dtype='<U6')]], dtype=object), array([[(array([[ 5101],
#                         [ 6393],
#                         [ 7665],
#                         [ 8949],
#                         [10061],
#                         [11077],
#                         [12345],
#                         [13457],
#                         [14825],
#                         [16221],
#                         [17633],
#                         [18681],
#                         [19841],
#                         [21253],
#                         [22697],
#                         [23753],
#                         [25149],
#                         [26181],
#                         [27333],
#                         [28541],
#                         [29929],
#                         [31001],
#                         [32541],
#                         [33921],
#                         [35033],
#                         [36445],
#                         [37985],
#                         [39177],
#                         [40273],
#                         [41813],
#                         [42925],
#                         [44065],
#                         [45161],
#                         [46281],
#                         [47717],
#                         [48877],
#                         [49909],
#                         [50949],
#                         [52385],
#                         [53869],
#                         [55133],
#                         [56529],
#                         [57673],
#                         [59069],
#                         [60149],
#                         [61261],
#                         [62497],
#                         [63561],
#                         [64761],
#                         [65993],
#                         [67245],
#                         [68721],
#                         [70121],
#                         [71429],
#                         [72785],
#                         [74009],
#                         [75533],
#                         [76645],
#                         [77929],
#                         [79105],
#                         [80185],
#                         [81233],
#                         [82613],
#                         [84121],
#                         [85629],
#                         [86773],
#                         [88089],
#                         [89601],
#                         [90757]], dtype=int32), array([[ 2],
#                         [10],
#                         [10],
#                         [ 8],
#                         [ 2],
#                         [10],
#                         [ 8],
#                         [ 1],
#                         [ 5],
#                         [ 4],
#                         [ 2],
#                         [10],
#                         [10],
#                         [ 8],
#                         [ 1],
#                         [ 5],
#                         [ 5],
#                         [ 5],
#                         [ 1],
#                         [ 5],
#                         [ 5],
#                         [ 5],
#                         [ 2],
#                         [10],
#                         [10],
#                         [ 8],
#                         [ 2],
#                         [10],
#                         [10],
#                         [ 8],
#                         [ 1],
#                         [ 5],
#                         [ 5],
#                         [ 9],
#                         [ 9],
#                         [ 5],
#                         [ 5],
#                         [ 5],
#                         [ 2],
#                         [10],
#                         [ 8],
#                         [ 1],
#                         [ 5],
#                         [ 4],
#                         [ 2],
#                         [10],
#                         [ 8],
#                         [ 1],
#                         [ 5],
#                         [ 9],
#                         [ 5],
#                         [ 9],
#                         [ 5],
#                         [ 5],
#                         [ 1],
#                         [ 5],
#                         [ 5],
#                         [ 4],
#                         [ 2],
#                         [10],
#                         [10],
#                         [ 6],
#                         [10],
#                         [ 8],
#                         [ 2],
#                         [10],
#                         [ 8],
#                         [ 2],
#                         [10]], dtype=uint8))                ]],
#                dtype=[('POS', 'O'), ('TYP', 'O')]))                                                                                ]],
#        dtype=[('Subject', 'O'), ('Session', 'O'), ('SampleRate', 'O'), ('Label', 'O'), ('EVENT', 'O')]))                                                                                      ]

# %%
# Check what exactly is in run[0][0]
print("run[0][0] type:", type(run[0][0]))
print("run[0][0]:", run[0][0])
# Out:
# run[0][0] type: <class 'numpy.ndarray'>
# run[0][0]: [[(array([[ 8987.96776658,  -853.57654873,  -754.98298091, ...,
#            5398.00564992, 21808.41282764,  6147.94176423],
#          [ 8979.71778182,  -860.98278505,  -753.70173327, ...,
#            5416.84936511, 21821.38155367,  6165.4417319 ],
#          [ 8980.99902946,  -856.67029301,  -749.04549188, ...,
#            5411.69312463, 21819.06905795,  6167.00422901],
#          ...,
#          [ 8933.09286798,  -685.7643588 ,  -560.88958954, ...,
#            5334.00576818, 21561.78828334,  6204.75415926],
#          [ 8925.31163235,  -692.70184599,  -568.98332459, ...,
#            5333.47451916, 21559.3195379 ,  6205.81665729],
#          [ 8919.03039396,  -697.2955875 ,  -574.7645639 , ...,
#            5339.44325813, 21562.53828195,  6210.59789846]]), array([[(array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[512]], dtype=uint16), array([[array(['Fp1'], dtype='<U3')],
#                  [array(['AF7'], dtype='<U3')],
#                  [array(['AF3'], dtype='<U3')],
#                  [array(['F1'], dtype='<U2')],
#                  [array(['F3'], dtype='<U2')],
#                  [array(['F5'], dtype='<U2')],
#                  [array(['F7'], dtype='<U2')],
#                  [array(['FT7'], dtype='<U3')],
#                  [array(['FC5'], dtype='<U3')],
#                  [array(['FC3'], dtype='<U3')],
#                  [array(['FC1'], dtype='<U3')],
#                  [array(['C1'], dtype='<U2')],
#                  [array(['C3'], dtype='<U2')],
#                  [array(['C5'], dtype='<U2')],
#                  [array(['T7'], dtype='<U2')],
#                  [array(['TP7'], dtype='<U3')],
#                  [array(['CP5'], dtype='<U3')],
#                  [array(['CP3'], dtype='<U3')],
#                  [array(['CP1'], dtype='<U3')],
#                  [array(['P1'], dtype='<U2')],
#                  [array(['P3'], dtype='<U2')],
#                  [array(['P5'], dtype='<U2')],
#                  [array(['P7'], dtype='<U2')],
#                  [array(['P9'], dtype='<U2')],
#                  [array(['PO7'], dtype='<U3')],
#                  [array(['PO3'], dtype='<U3')],
#                  [array(['O1'], dtype='<U2')],
#                  [array(['Iz'], dtype='<U2')],
#                  [array(['Oz'], dtype='<U2')],
#                  [array(['POz'], dtype='<U3')],
#                  [array(['Pz'], dtype='<U2')],
#                  [array(['CPz'], dtype='<U3')],
#                  [array(['Fpz'], dtype='<U3')],
#                  [array(['Fp2'], dtype='<U3')],
#                  [array(['AF8'], dtype='<U3')],
#                  [array(['AF4'], dtype='<U3')],
#                  [array(['AFz'], dtype='<U3')],
#                  [array(['Fz'], dtype='<U2')],
#                  [array(['F2'], dtype='<U2')],
#                  [array(['F4'], dtype='<U2')],
#                  [array(['F6'], dtype='<U2')],
#                  [array(['F8'], dtype='<U2')],
#                  [array(['FT8'], dtype='<U3')],
#                  [array(['FC6'], dtype='<U3')],
#                  [array(['FC4'], dtype='<U3')],
#                  [array(['FC2'], dtype='<U3')],
#                  [array(['FCz'], dtype='<U3')],
#                  [array(['Cz'], dtype='<U2')],
#                  [array(['C2'], dtype='<U2')],
#                  [array(['C4'], dtype='<U2')],
#                  [array(['C6'], dtype='<U2')],
#                  [array(['T8'], dtype='<U2')],
#                  [array(['TP8'], dtype='<U3')],
#                  [array(['CP6'], dtype='<U3')],
#                  [array(['CP4'], dtype='<U3')],
#                  [array(['CP2'], dtype='<U3')],
#                  [array(['P2'], dtype='<U2')],
#                  [array(['P4'], dtype='<U2')],
#                  [array(['P6'], dtype='<U2')],
#                  [array(['P8'], dtype='<U2')],
#                  [array(['P10'], dtype='<U3')],
#                  [array(['PO8'], dtype='<U3')],
#                  [array(['PO4'], dtype='<U3')],
#                  [array(['O2'], dtype='<U2')],
#                  [array(['Status'], dtype='<U6')]], dtype=object), array([[(array([[ 5101],
#                          [ 6393],
#                          [ 7665],
#                          [ 8949],
#                          [10061],
#                          [11077],
#                          [12345],
#                          [13457],
#                          [14825],
#                          [16221],
#                          [17633],
#                          [18681],
#                          [19841],
#                          [21253],
#                          [22697],
#                          [23753],
#                          [25149],
#                          [26181],
#                          [27333],
#                          [28541],
#                          [29929],
#                          [31001],
#                          [32541],
#                          [33921],
#                          [35033],
#                          [36445],
#                          [37985],
#                          [39177],
#                          [40273],
#                          [41813],
#                          [42925],
#                          [44065],
#                          [45161],
#                          [46281],
#                          [47717],
#                          [48877],
#                          [49909],
#                          [50949],
#                          [52385],
#                          [53869],
#                          [55133],
#                          [56529],
#                          [57673],
#                          [59069],
#                          [60149],
#                          [61261],
#                          [62497],
#                          [63561],
#                          [64761],
#                          [65993],
#                          [67245],
#                          [68721],
#                          [70121],
#                          [71429],
#                          [72785],
#                          [74009],
#                          [75533],
#                          [76645],
#                          [77929],
#                          [79105],
#                          [80185],
#                          [81233],
#                          [82613],
#                          [84121],
#                          [85629],
#                          [86773],
#                          [88089],
#                          [89601],
#                          [90757]], dtype=int32), array([[ 2],
#                          [10],
#                          [10],
#                          [ 8],
#                          [ 2],
#                          [10],
#                          [ 8],
#                          [ 1],
#                          [ 5],
#                          [ 4],
#                          [ 2],
#                          [10],
#                          [10],
#                          [ 8],
#                          [ 1],
#                          [ 5],
#                          [ 5],
#                          [ 5],
#                          [ 1],
#                          [ 5],
#                          [ 5],
#                          [ 5],
#                          [ 2],
#                          [10],
#                          [10],
#                          [ 8],
#                          [ 2],
#                          [10],
#                          [10],
#                          [ 8],
#                          [ 1],
#                          [ 5],
#                          [ 5],
#                          [ 9],
#                          [ 9],
#                          [ 5],
#                          [ 5],
#                          [ 5],
#                          [ 2],
#                          [10],
#                          [ 8],
#                          [ 1],
#                          [ 5],
#                          [ 4],
#                          [ 2],
#                          [10],
#                          [ 8],
#                          [ 1],
#                          [ 5],
#                          [ 9],
#                          [ 5],
#                          [ 9],
#                          [ 5],
#                          [ 5],
#                          [ 1],
#                          [ 5],
#                          [ 5],
#                          [ 4],
#                          [ 2],
#                          [10],
#                          [10],
#                          [ 6],
#                          [10],
#                          [ 8],
#                          [ 2],
#                          [10],
#                          [ 8],
#                          [ 2],
#                          [10]], dtype=uint8))                ]],
#                 dtype=[('POS', 'O'), ('TYP', 'O')]))                                                                                ]],
#         dtype=[('Subject', 'O'), ('Session', 'O'), ('SampleRate', 'O'), ('Label', 'O'), ('EVENT', 'O')]))                                                                                      ]]

# %%
# Get the inner tuple that has EEG and metadata
inner_struct = main_struct[0]

print("Length of inner_struct:", len(inner_struct))
print("Type of inner_struct[0]:", type(inner_struct[0]))

# EEG data (first item)
eeg_data = inner_struct[0]
print("✅ EEG data shape:", eeg_data.shape)

# Metadata (second item)
metadata_array = inner_struct[1]

# Metadata array is deeply nested: array([[(array([...metadata...]))]])
metadata_raw = metadata_array[0][0]

# Sample rate
sample_rate = metadata_raw[2][0][0]
print("✅ Sample rate:", sample_rate)

# Channel names
chan_info_raw = metadata_raw[3][0]
channel_names = [c[0] for c in chan_info_raw]
print("✅ First 10 channel names:", channel_names[:10])

# Events
events_raw = metadata_raw[4][0]
event_positions = events_raw[0][0]
event_types = events_raw[1][0]
print("✅ First 5 event positions:", event_positions[:5])
print("✅ First 5 event types:", event_types[:5])
# Out:
# Length of inner_struct: 1
# Type of inner_struct[0]: <class 'numpy.void'>
# ✅ EEG data shape: ()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-68-1829799770.py in <cell line: 0>()
#      10
#      11 # Metadata (second item)
# ---> 12 metadata_array = inner_struct[1]
#      13
#      14 # Metadata array is deeply nested: array([[(array([...metadata...]))]])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
